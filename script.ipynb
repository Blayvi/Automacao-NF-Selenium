# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Entrando no site e preenchendo 1 item qualquer

# %%
# 1- Entrando no site

# essa configuração é para remover a mensagem de erro exibida ao fazer o download da NF
options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\isvbl\downloads",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

driver = webdriver.Chrome(options=options)
driver.get(r'file:///C:/Users/isvbl/OneDrive/%C3%81rea%20de%20Trabalho/Automa%C3%A7%C3%A3o%20NF/login.html')

# 2 - Efetuando o login

driver.find_element(By.XPATH, '/html/body/div/form/input[1]').send_keys('isaac@gmail.com')

driver.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys('123456')

driver.find_element(By.XPATH, '/html/body/div/form/button').click()

# 3 - Preencher os dados na NF
# nome
driver.find_element(By.NAME, 'nome').send_keys('TreineeJr')

# Endereço
driver.find_element(By.NAME, 'endereco').send_keys('Rua sla oq')

# Bairro
driver.find_element(By.NAME, 'bairro').send_keys('Centro')

# Município
driver.find_element(By.NAME, 'municipio').send_keys('Nilópolis')

# CEP
driver.find_element(By.NAME, 'cep').send_keys('40228922')

# #UF
driver.find_element(By.NAME, 'uf').send_keys('RJ')

# CNPJ/CPF
driver.find_element(By.NAME, 'cnpj').send_keys('74854/0001-00')

# Inscrição Estadual
driver.find_element(By.NAME, 'inscricao').send_keys('286738')

# Descrição do Produto 
texto = "Valor referente aos serviços prestados"
driver.find_element(By.NAME, 'descricao').send_keys(texto)

# Quantidade
driver.find_element(By.NAME, 'quantidade').send_keys('10')

# Valor Unitário
driver.find_element(By.NAME, 'valor_unitario').send_keys('15')

# Valor total
driver.find_element(By.NAME, 'total').send_keys('150')

# 4 - Emitir a nota fiscal
driver.find_element(By.CLASS_NAME, 'registerbtn').click()

# %% [markdown]
# ### Emitindo várias NFs baseadas em arquivos de uma planilha do excel

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 
import pandas as pd

# %%
# 1- Entrando no site (Apenas 1x)

# essa configuração é para remover a mensagem de erro exibida ao fazer o download da NF
options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\isvbl\downloads",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

driver = webdriver.Chrome(options=options)
driver.get(r'file:///C:/Users/isvbl/OneDrive/%C3%81rea%20de%20Trabalho/Automa%C3%A7%C3%A3o%20NF/login.html')


# 2 - Efetuando o login (apenas 1x)

driver.find_element(By.XPATH, '/html/body/div/form/input[1]').send_keys('isaac@gmail.com')

driver.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys('123456')

driver.find_element(By.XPATH, '/html/body/div/form/button').click()

# 3 - Importando a base de clientes (1x)
tabela = pd.read_excel('NotasEmitir.xlsx')

# 4- Preencher os dados da NF e emitir (várias vezes)

for linha in tabela.index:
    # nome
    driver.find_element(By.NAME, 'nome').send_keys(tabela.loc[linha, "Cliente"])

    # Endereço
    driver.find_element(By.NAME, 'endereco').send_keys(tabela.loc[linha, "Endereço"])

    # Bairro
    driver.find_element(By.NAME, 'bairro').send_keys(tabela.loc[linha, "Bairro"])

    # Município
    driver.find_element(By.NAME, 'municipio').send_keys(tabela.loc[linha, "Municipio"])

    # CEP
    driver.find_element(By.NAME, 'cep').send_keys(str(tabela.loc[linha, "CEP"]))

    # #UF
    driver.find_element(By.NAME, 'uf').send_keys(tabela.loc[linha, "UF"])

    # CNPJ/CPF
    driver.find_element(By.NAME, 'cnpj').send_keys(str(tabela.loc[linha, "CPF/CNPJ"]))

    # Inscrição Estadual
    driver.find_element(By.NAME, 'inscricao').send_keys(str(tabela.loc[linha, "Inscricao Estadual"]))

    # Descrição do Produto 
    driver.find_element(By.NAME, 'descricao').send_keys(tabela.loc[linha, "Descrição"])

    # Quantidade
    driver.find_element(By.NAME, 'quantidade').send_keys(str(tabela.loc[linha, "Quantidade"]))

    # Valor Unitário
    driver.find_element(By.NAME, 'valor_unitario').send_keys(str(tabela.loc[linha, "Valor Unitario"]))

    # Valor total
    driver.find_element(By.NAME, 'total').send_keys(str(tabela.loc[linha, "Valor Total"]))

    # Emitir a nota fiscal
    driver.find_element(By.CLASS_NAME, 'registerbtn').click()

    # Limpar o formulário ( nesse caso só recarregar a página)
    driver.refresh()

# %%
# Ao executar o código, percebe-se que todos os int64 apresentam erro, portanto foram transformados em str no meio do código
tabela.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cliente             30 non-null     object
#  1   CPF/CNPJ            30 non-null     int64
#  2   CEP                 30 non-null     int64
#  3   Endereço            30 non-null     object
#  4   Bairro              30 non-null     object
#  5   Municipio           30 non-null     object
#  6   UF                  30 non-null     object
#  7   Inscricao Estadual  30 non-null     int64
#  8   Descrição           30 non-null     object
#  9   Quantidade          30 non-null     int64
#  10  Valor Unitario      30 non-null     int64
#  11  Valor Total         30 non-null     int64
# dtypes: int64(6), object(6)
# memory usage: 2.9+ KB
